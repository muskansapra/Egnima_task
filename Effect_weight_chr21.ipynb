# %% [markdown]
# <a href="https://colab.research.google.com/github/muskansapra/Egnima_task/blob/main/Effect_weight_chr21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np
# upload file as numpy array
File_data = np.loadtxt("/home/hist.txt", dtype=float)
# plot histogram
plt.hist(File_data, bins=20, edgecolor='black')
plt.title('Effect weight on chromosome 21')
plt.xlabel('effect_weight')
plt.ylabel('Frequency')
plt.show()
